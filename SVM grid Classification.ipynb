# %%
#importing the libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
datasets=pd.read_csv("Social_Network_Ads.csv")

# %%
datasets
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
datasets=pd.get_dummies(datasets,drop_first=True)

# %%
datasets
# Out:
#       User ID  Age  EstimatedSalary  Purchased  Gender_Male
# 0    15624510   19            19000          0            1
# 1    15810944   35            20000          0            1
# 2    15668575   26            43000          0            0
# 3    15603246   27            57000          0            0
# 4    15804002   19            76000          0            1
# ..        ...  ...              ...        ...          ...
# 395  15691863   46            41000          1            0
# 396  15706071   51            23000          1            1
# 397  15654296   50            20000          1            0
# 398  15755018   36            33000          0            1
# 399  15594041   49            36000          1            0
#
# [400 rows x 5 columns]

# %%
indep=datasets[['Age', 'EstimatedSalary','Gender_Male']]
dep=datasets['Purchased']

# %%
indep
# Out:
#      Age  EstimatedSalary  Gender_Male
# 0     19            19000            1
# 1     35            20000            1
# 2     26            43000            0
# 3     27            57000            0
# 4     19            76000            1
# ..   ...              ...          ...
# 395   46            41000            0
# 396   51            23000            1
# 397   50            20000            0
# 398   36            33000            1
# 399   49            36000            0
#
# [400 rows x 3 columns]

# %%
dep
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 395    1
# 396    1
# 397    1
# 398    0
# 399    1
# Name: Purchased, Length: 400, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(indep,dep,test_size=0.30,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.svm import SVC

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {'kernel':['linear','rbf','poly','sigmoid'],
             'gamma':['auto','scale'],
             'C':[10,100,1000,2000,3000]} 



grid = GridSearchCV(SVC(), param_grid, refit = True, verbose = 3,n_jobs=-1,scoring='f1_weighted') 
   
# fitting the model for grid search 
grid.fit(X_train, y_train)
# Out:
# C:\Users\rajah\anaconda3\envs\pugazh\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# Fitting 3 folds for each of 40 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:    3.8s finished
# GridSearchCV(cv='warn', error_score='raise-deprecating',
#              estimator=SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#                            decision_function_shape='ovr', degree=3,
#                            gamma='auto_deprecated', kernel='rbf', max_iter=-1,
#                            probability=False, random_state=None, shrinking=True,
#                            tol=0.001, verbose=False),
#              iid='warn', n_jobs=-1,
#              param_grid={'C': [10, 100, 1000, 2000, 3000],
#                          'gamma': ['auto', 'scale'],
#                          'kernel': ['linear', 'rbf', 'poly', 'sigmoid']},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring='f1_weighted', verbose=3)

# %%
# print best parameter after tuning 
#print(grid.best_params_) 
re=grid.cv_results_
#print(re)
grid_predictions = grid.predict(X_test) 
   

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, grid_predictions)



# print classification report 
from sklearn.metrics import classification_report
clf_report = classification_report(y_test, grid_predictions)

# %%
from sklearn.metrics import f1_score
f1_macro=f1_score(y_test,grid_predictions,average='weighted')
print("The f1_macro value for best parameter {}:".format(grid.best_params_),f1_macro)
# Out:
# The f1_macro value for best parameter {'C': 10, 'gamma': 'auto', 'kernel': 'rbf'}: 0.9171245421245421

# %%
print("The confusion Matrix:\n",cm)
# Out:
# The confusion Matrix:
#  [[73  6]
#  [ 4 37]]

# %%
print("The report:\n",clf_report)
# Out:
# The report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.92      0.94        79
#            1       0.86      0.90      0.88        41
#
#     accuracy                           0.92       120
#    macro avg       0.90      0.91      0.91       120
# weighted avg       0.92      0.92      0.92       120

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0        0.005207      0.007364         0.000000        0.000000      10
# 1        0.005207      0.007364         0.000000        0.000000      10
# 2        0.005207      0.007364         0.000000        0.000000      10
# 3        0.005207      0.007364         0.000000        0.000000      10
# 4        0.005207      0.007364         0.000000        0.000000      10
# 5        0.000000      0.000000         0.000000        0.000000      10
# 6        0.005207      0.007363         0.005207        0.007363      10
# 7        0.000000      0.000000         0.000000        0.000000      10
# 8        0.010414      0.007364         0.005207        0.007364     100
# 9        0.010414      0.007364         0.000000        0.000000     100
# 10       0.010414      0.014728         0.005207        0.007364     100
# 11       0.005207      0.007364         0.005207        0.007364     100
# 12       0.005207      0.007364         0.000000        0.000000     100
# 13       0.005207      0.007364         0.000000        0.000000     100
# 14       0.015621      0.012755         0.000000        0.000000     100
# 15       0.000000      0.000000         0.005207        0.007364     100
# 16       0.056023      0.008604         0.000665        0.000940    1000
# 17       0.007201      0.006435         0.000333        0.000470    1000
# 18       0.076926      0.045390         0.000000        0.000000    1000
# 19       0.000000      0.000000         0.000000        0.000000    1000
# 20       0.061305      0.013484         0.001625        0.002298    1000
# 21       0.005207      0.007364         0.005207        0.007364    1000
# 22       0.053830      0.015322         0.000332        0.000470    1000
# 23       0.000665      0.000470         0.000655        0.000464    1000
# 24       0.228458      0.125611         0.005207        0.007364    2000
# 25       0.005207      0.007364         0.000000        0.000000    2000
# 26       0.135960      0.066492         0.000000        0.000000    2000
# 27       0.005207      0.007364         0.000000        0.000000    2000
# 28       0.195554      0.092297         0.010414        0.007364    2000
# 29       0.006832      0.009662         0.000681        0.000964    2000
# 30       0.126489      0.090083         0.000000        0.000000    2000
# 31       0.005207      0.007364         0.000000        0.000000    2000
# 32       0.354561      0.302497         0.000000        0.000000    3000
# 33       0.010414      0.007364         0.000000        0.000000    3000
# 34       0.161424      0.053101         0.005203        0.007358    3000
# 35       0.000000      0.000000         0.000000        0.000000    3000
# 36       0.307112      0.248595         0.000000        0.000000    3000
# 37       0.015610      0.000016         0.000000        0.000000    3000
# 38       0.166627      0.082987         0.000000        0.000000    3000
# 39       0.005207      0.007364         0.000000        0.000000    3000
#
#    param_gamma param_kernel  \
# 0         auto       linear
# 1         auto          rbf
# 2         auto         poly
# 3         auto      sigmoid
# 4        scale       linear
# 5        scale          rbf
# 6        scale         poly
# 7        scale      sigmoid
# 8         auto       linear
# 9         auto          rbf
# 10        auto         poly
# 11        auto      sigmoid
# 12       scale       linear
# 13       scale          rbf
# 14       scale         poly
# 15       scale      sigmoid
# 16        auto       linear
# 17        auto          rbf
# 18        auto         poly
# 19        auto      sigmoid
# 20       scale       linear
# 21       scale          rbf
# 22       scale         poly
# 23       scale      sigmoid
# 24        auto       linear
# 25        auto          rbf
# 26        auto         poly
# 27        auto      sigmoid
# 28       scale       linear
# 29       scale          rbf
# 30       scale         poly
# 31       scale      sigmoid
# 32        auto       linear
# 33        auto          rbf
# 34        auto         poly
# 35        auto      sigmoid
# 36       scale       linear
# 37       scale          rbf
# 38       scale         poly
# 39       scale      sigmoid
#
#                                                params  split0_test_score  \
# 0      {'C': 10, 'gamma': 'auto', 'kernel': 'linear'}           0.784017
# 1         {'C': 10, 'gamma': 'auto', 'kernel': 'rbf'}           0.893617
# 2        {'C': 10, 'gamma': 'auto', 'kernel': 'poly'}           0.858980
# 3     {'C': 10, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.691578
# 4     {'C': 10, 'gamma': 'scale', 'kernel': 'linear'}           0.784017
# 5        {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}           0.893617
# 6       {'C': 10, 'gamma': 'scale', 'kernel': 'poly'}           0.858980
# 7    {'C': 10, 'gamma': 'scale', 'kernel': 'sigmoid'}           0.691578
# 8     {'C': 100, 'gamma': 'auto', 'kernel': 'linear'}           0.784017
# 9        {'C': 100, 'gamma': 'auto', 'kernel': 'rbf'}           0.893617
# 10      {'C': 100, 'gamma': 'auto', 'kernel': 'poly'}           0.847403
# 11   {'C': 100, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.736252
# 12   {'C': 100, 'gamma': 'scale', 'kernel': 'linear'}           0.784017
# 13      {'C': 100, 'gamma': 'scale', 'kernel': 'rbf'}           0.893617
# 14     {'C': 100, 'gamma': 'scale', 'kernel': 'poly'}           0.847403
# 15  {'C': 100, 'gamma': 'scale', 'kernel': 'sigmoid'}           0.736252
# 16   {'C': 1000, 'gamma': 'auto', 'kernel': 'linear'}           0.784017
# 17      {'C': 1000, 'gamma': 'auto', 'kernel': 'rbf'}           0.882589
# 18     {'C': 1000, 'gamma': 'auto', 'kernel': 'poly'}           0.835667
# 19  {'C': 1000, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.746165
# 20  {'C': 1000, 'gamma': 'scale', 'kernel': 'linear'}           0.784017
# 21     {'C': 1000, 'gamma': 'scale', 'kernel': 'rbf'}           0.882589
# 22    {'C': 1000, 'gamma': 'scale', 'kernel': 'poly'}           0.835667
# 23  {'C': 1000, 'gamma': 'scale', 'kernel': 'sigmo...           0.746165
# 24   {'C': 2000, 'gamma': 'auto', 'kernel': 'linear'}           0.784017
# 25      {'C': 2000, 'gamma': 'auto', 'kernel': 'rbf'}           0.893617
# 26     {'C': 2000, 'gamma': 'auto', 'kernel': 'poly'}           0.835667
# 27  {'C': 2000, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.746165
# 28  {'C': 2000, 'gamma': 'scale', 'kernel': 'linear'}           0.784017
# 29     {'C': 2000, 'gamma': 'scale', 'kernel': 'rbf'}           0.893617
# 30    {'C': 2000, 'gamma': 'scale', 'kernel': 'poly'}           0.835667
# 31  {'C': 2000, 'gamma': 'scale', 'kernel': 'sigmo...           0.746165
# 32   {'C': 3000, 'gamma': 'auto', 'kernel': 'linear'}           0.784017
# 33      {'C': 3000, 'gamma': 'auto', 'kernel': 'rbf'}           0.872340
# 34     {'C': 3000, 'gamma': 'auto', 'kernel': 'poly'}           0.835667
# 35  {'C': 3000, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.746165
# 36  {'C': 3000, 'gamma': 'scale', 'kernel': 'linear'}           0.784017
# 37     {'C': 3000, 'gamma': 'scale', 'kernel': 'rbf'}           0.872340
# 38    {'C': 3000, 'gamma': 'scale', 'kernel': 'poly'}           0.835667
# 39  {'C': 3000, 'gamma': 'scale', 'kernel': 'sigmo...           0.746165
#
#     split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 0            0.739369           0.900383         0.807838        0.067766
# 1            0.861345           0.946396         0.900428        0.034997
# 2            0.801769           0.923274         0.861333        0.049544
# 3            0.731982           0.761828         0.728331        0.028820
# 4            0.739369           0.900383         0.807838        0.067766
# 5            0.861345           0.935484         0.896804        0.030298
# 6            0.801769           0.923274         0.861333        0.049544
# 7            0.731982           0.751882         0.725027        0.025124
# 8            0.739369           0.911897         0.811662        0.073004
# 9            0.872288           0.924486         0.896786        0.021390
# 10           0.801769           0.900383         0.849843        0.040224
# 11           0.722014           0.798176         0.752090        0.033017
# 12           0.739369           0.911897         0.811662        0.073004
# 13           0.872288           0.924486         0.896786        0.021390
# 14           0.801769           0.900383         0.849843        0.040224
# 15           0.722014           0.798176         0.752090        0.033017
# 16           0.739369           0.911897         0.811662        0.073004
# 17           0.861345           0.844205         0.862784        0.015717
# 18           0.801769           0.900383         0.845903        0.040840
# 19           0.722014           0.798176         0.755418        0.031727
# 20           0.739369           0.911897         0.811662        0.073004
# 21           0.861345           0.844205         0.862784        0.015717
# 22           0.801769           0.900383         0.845903        0.040840
# 23           0.722014           0.798176         0.755418        0.031727
# 24           0.739369           0.911897         0.811662        0.073004
# 25           0.861345           0.832123         0.862473        0.025140
# 26           0.801769           0.900383         0.845903        0.040840
# 27           0.722014           0.798176         0.755418        0.031727
# 28           0.739369           0.911897         0.811662        0.073004
# 29           0.861345           0.832123         0.862473        0.025140
# 30           0.801769           0.900383         0.845903        0.040840
# 31           0.722014           0.798176         0.755418        0.031727
# 32           0.739369           0.911897         0.811662        0.073004
# 33           0.851533           0.830023         0.851374        0.017291
# 34           0.801769           0.900383         0.845903        0.040840
# 35           0.722014           0.798176         0.755418        0.031727
# 36           0.739369           0.911897         0.811662        0.073004
# 37           0.851533           0.830023         0.851374        0.017291
# 38           0.801769           0.900383         0.845903        0.040840
# 39           0.722014           0.798176         0.755418        0.031727
#
#     rank_test_score
# 0                29
# 1                 1
# 2                 9
# 3                39
# 4                29
# 5                 2
# 6                 9
# 7                40
# 8                21
# 9                 3
# 10               13
# 11               37
# 12               21
# 13                3
# 14               13
# 15               37
# 16               21
# 17                5
# 18               15
# 19               31
# 20               21
# 21                5
# 22               15
# 23               31
# 24               21
# 25                7
# 26               15
# 27               31
# 28               21
# 29                7
# 30               15
# 31               31
# 32               21
# 33               11
# 34               15
# 35               31
# 36               21
# 37               11
# 38               15
# 39               31
